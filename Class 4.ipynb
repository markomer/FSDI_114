# %% [markdown]
# # Mini Challenge 1
# ### Use what we learned last class to create a simple linked list that allows us to append and insert new nodes (not remove -- yet).
#
# The following test cases acn be used to validate your results:
#
# ```
# mylist = LinkedList()
# for i in range(5):
#     mylist.append(i)
#
# current = mylist.head
# for i in range(5):
#     assert current.data = i
#
# mylist.insert(0, -1)
#
# assert mylist.head.data == -1
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def append(self, item):
        new_node = Node(item)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            
    def insert(self, index, item):  # this method should insert a new node with "item" for data BEFORE the target index.
        new_node = Node(item)
        if not self.head:
            self.head = new_node
        elif index == 0:
            new_node.next = self.head
            self.head = new_node
        else:
            counter = 0
            current = self.head
            prev = None
            while current.next and index != counter: # while current.next != 1...
                prev = current
                current = current.next
                counter += 1
            if index == counter:
                prev.next = new_node
                new_node.next = current
            else:
                current.next = new_node
                
                    #remove(self, value, /)
                    #Remove first occurrence of value.
                    #Raises ValueError if the value is not present.   
    def remove(self, value):
        current = self.head
        if not current:
            raise ValueError("There's nothing to remove!")
        if current.data == value:
            self.head = current.next
        
        else:
            prev = None
            while current.next and current.data != value:
                prev = current
                current = current.next
            if current.data == value:
                prev.next = current.next
            else: 
                raise ValueError("%s is not in list." % value)
                
    def __str__(self):
        output_str = "["
        current = self.head
        output_str += "%s" % current.data
        current = current.next
        
        while current:
            output_str += ", %s" % current.data
            current = current.next
        output_str += "]"
        return output_str
  
    def __len__(self):
        current = self.head
        length = 0
        while current:
            current = current.next
            length += 1
        return length
    

    def count(num_list, x):
        count = 0
        for ele in num_list:
            if (ele == x):
                count = count + 1
        return count

    num_list = [8, 6, 8, 10, 8, 20, 10, 8, 8]
    x = 8
    print('{} has occurred {} times'.format(x, count(num_list, x)))
    

    def index(this_list, start=0, stop=9223372036854775807, /):
        this_list = [11,22,33,44,11,55,66,11,88]
        for lm in this_list:
            if lm==11:
                print("value is = {} and index is = {}".format(lm,this_list.index(lm)))
            else:
                print("value is = {} and index is = {}".format(lm,this_list.index(lm)))
# Out:
# 8 has occurred 5 times

# %%
mylist = LinkedList()
for i in range(5):
    mylist.append(i)

current = mylist.head
for i in range(5):
    assert current.data == i
    current = current.next

mylist.insert(0, -1)

assert mylist.head.data == -1

print(mylist)
print(len(mylist))

# %%
x = [0, 1, 2, 3, 4]

print(x)

help(x)
# Out:
# [0, 1, 2, 3, 4]
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...
